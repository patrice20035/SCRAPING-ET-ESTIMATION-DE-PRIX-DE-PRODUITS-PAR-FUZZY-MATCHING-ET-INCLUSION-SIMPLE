# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import os
import time
import re
from rapidfuzz import fuzz

# Liste des catégories
CATEGORIES = [
    'bio-et-ecologie', 'fruits-et-legumes', 'viandes-et-poissons', 'pains-et-patisseries',
    'cremerie-et-produits-laitiers', 'charcuterie-et-traiteur', 'surgeles', 'epicerie-salee',
    'epicerie-sucree', 'beaute-et-sante', 'boissons', 'nutrition-et-vegetale', 'hygiene-et-beaute',
    'entretien-et-nettoyage', 'animalerie', 'bebe', 'jardin', 'entretien-de-la-maison',
    'maison-et-decoration', 'cuisine', 'gros-electromenager', 'bricolage',
    'velo-trotinettes-et-loisirs', 'smartphones-et-objets-connectes', 'image-et-son',
    'informatique-et-bureau', 'jeux-videos', 'jeux-et-jouets', 'mode-et-bagagerie'
]

# Dossier de sortie
OUTPUT_FOLDER = r"C:/Users/DELL/OneDrive - etu.unistra.fr/Bureau/cours fac/PROGRAMMATION PYTHON/PROJET/Output"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Mode utilisateur
mode = input("Souhaitez-vous scraper des promotions, des produits, ou estimer un prix ? [promotions/products/estimate] : ").strip().lower()
while mode not in ["promotions", "products", "estimate"]:
    mode = input("Veuillez entrer 'promotions', 'products', ou 'estimate' : ").strip().lower()

# Sélection de catégorie si nécessaire
if mode in ["products", "estimate"]:
    print("\nCatégories disponibles :")
    for idx, cat in enumerate(CATEGORIES, 1):
        print(f" {idx}. {cat}")
    while True:
        try:
            cat_choice = int(input("Choisissez le numéro de la catégorie : ").strip())
            if 1 <= cat_choice <= len(CATEGORIES):
                categorie = CATEGORIES[cat_choice - 1]
                break
            else:
                print("Numéro invalide. Réessayez.")
        except ValueError:
            print("Veuillez entrer un numéro valide.")
else:
    categorie = None

# Scraping toutes les pages
def scrap_all_pages(url_base):
    driver = webdriver.Chrome()
    all_data = []
    page = 0
    while True:
        driver.get(f"{url_base}&page={page}")
        time.sleep(5)
        products = driver.find_elements(By.CLASS_NAME, "product-list-grid__item")
        print(f"Scraping page {page + 1} : {len(products)} produits")

        if not products:
            break  # Stop si aucune donnée

        for p in products:
            try:
                name = p.find_element(By.CSS_SELECTOR, "a.product-card-title").text
            except:
                name = None

            try:
                price_block = p.find_element(By.CSS_SELECTOR, "div.product-price__amount--main")
                price_text = price_block.text
                clean_price = re.sub(r'[^\d,\.]', '', price_text)
                price = float(clean_price.replace(',', '.'))
            except:
                price = None

            all_data.append({
                "product_name": name,
                "price": price,
                "page": page + 1
            })

        page += 1  # Passer à la page suivante

    driver.quit()
    return pd.DataFrame(all_data)

# Mode promotions / products
if mode in ["promotions", "products"]:
    if mode == "promotions":
        base_url = "https://www.carrefour.fr/promotions?noRedirect=1"
        df = scrap_all_pages(base_url)
        filename = "carrefour_promotions_allpages.csv"
    else:
        base_url = f"https://www.carrefour.fr/r/{categorie}?noRedirect=1"
        df = scrap_all_pages(base_url)
        filename = f"carrefour_products_{categorie}_allpages.csv"

    # Sauvegarde CSV
    csv_path = os.path.join(OUTPUT_FOLDER, filename)
    df.to_csv(csv_path, index=False)
    print(f"✅ Fichier CSV enregistré : {csv_path}")
    print(df.head())

# Mode estimate
elif mode == "estimate":
    produit_cible = input("Saisissez le nom du produit à estimer : ").strip().lower()
    base_url = f"https://www.carrefour.fr/r/{categorie}?noRedirect=1"
    df = scrap_all_pages(base_url)

    if df.empty:
        print("⚠️ Aucun produit trouvé dans cette catégorie.")
    else:
        df['similarity'] = df['product_name'].apply(lambda x: fuzz.partial_ratio(produit_cible, x.lower()) if pd.notnull(x) else 0)
        similaires = df[df['similarity'] >= 60]

        if similaires.empty:
            print("⚠️ Aucun produit similaire trouvé.")
        else:
            prix_moyen = similaires['price'].mean()
            prix_min = similaires['price'].min()
            prix_max = similaires['price'].max()
            print("\nProduits similaires trouvés :")
            print(similaires[['product_name', 'price']])
            print(f"\nNombre de produits similaires : {len(similaires)}")
            print(f"Prix estimé moyen : {prix_moyen:.2f} €")
            print(f"Prix minimum : {prix_min:.2f} €, Prix maximum : {prix_max:.2f} €")
# Out:
# Souhaitez-vous scraper des promotions, des produits, ou estimer un prix ? [promotions/products/estimate] :  estimate
# Catégories disponibles :
#  1. bio-et-ecologie
#  2. fruits-et-legumes
#  3. viandes-et-poissons
#  4. pains-et-patisseries
#  5. cremerie-et-produits-laitiers
#  6. charcuterie-et-traiteur
#  7. surgeles
#  8. epicerie-salee
#  9. epicerie-sucree
#  10. beaute-et-sante
#  11. boissons
#  12. nutrition-et-vegetale
#  13. hygiene-et-beaute
#  14. entretien-et-nettoyage
#  15. animalerie
#  16. bebe
#  17. jardin
#  18. entretien-de-la-maison
#  19. maison-et-decoration
#  20. cuisine
#  21. gros-electromenager
#  22. bricolage
#  23. velo-trotinettes-et-loisirs
#  24. smartphones-et-objets-connectes
#  25. image-et-son
#  26. informatique-et-bureau
#  27. jeux-videos
#  28. jeux-et-jouets
#  29. mode-et-bagagerie
# Choisissez le numéro de la catégorie :  1
# Saisissez le nom du produit à estimer :  pomme
# Scraping page 1 : 35 produits
# Scraping page 2 : 35 produits
# Scraping page 3 : 35 produits
# Scraping page 4 : 35 produits
# Scraping page 5 : 35 produits
# Scraping page 6 : 35 produits
# Scraping page 7 : 35 produits
# Scraping page 8 : 35 produits
# Scraping page 9 : 35 produits
# Scraping page 10 : 35 produits
# Scraping page 11 : 35 produits
# Scraping page 12 : 35 produits
# Scraping page 13 : 35 produits
# Scraping page 14 : 35 produits
# Scraping page 15 : 35 produits
# Scraping page 16 : 35 produits
# Scraping page 17 : 35 produits
# Scraping page 18 : 35 produits
# Scraping page 19 : 35 produits
# Scraping page 20 : 35 produits
# Scraping page 21 : 35 produits
# Scraping page 22 : 35 produits
# Scraping page 23 : 35 produits
# Scraping page 24 : 35 produits
# Scraping page 25 : 35 produits
# Scraping page 26 : 35 produits
# Scraping page 27 : 35 produits
# Scraping page 28 : 35 produits
# Scraping page 29 : 35 produits
# Scraping page 30 : 35 produits
# Scraping page 31 : 35 produits
# Scraping page 32 : 35 produits
# Scraping page 33 : 35 produits
# Scraping page 34 : 35 produits
# Scraping page 35 : 35 produits
# Scraping page 36 : 35 produits
# Scraping page 37 : 35 produits
# Scraping page 38 : 35 produits
# Scraping page 39 : 35 produits
# Scraping page 40 : 35 produits
# Scraping page 41 : 35 produits
# Scraping page 42 : 35 produits
# Scraping page 43 : 35 produits
# Scraping page 44 : 35 produits
# Scraping page 45 : 35 produits
# Scraping page 46 : 35 produits
# Scraping page 47 : 35 produits
# Scraping page 48 : 35 produits
# Scraping page 49 : 35 produits
# Scraping page 50 : 35 produits
# Scraping page 51 : 35 produits
# Scraping page 52 : 35 produits
# Scraping page 53 : 35 produits
# Scraping page 54 : 35 produits
# Scraping page 55 : 35 produits
# Scraping page 56 : 35 produits
# Scraping page 57 : 35 produits
# Scraping page 58 : 35 produits
# Scraping page 59 : 35 produits
# Scraping page 60 : 35 produits
# Scraping page 61 : 35 produits
# Scraping page 62 : 35 produits
# Scraping page 63 : 35 produits
# Scraping page 64 : 35 produits
# Scraping page 65 : 35 produits
# Scraping page 66 : 35 produits
# Scraping page 67 : 35 produits
# Scraping page 68 : 35 produits
# Scraping page 69 : 35 produits
# Scraping page 70 : 35 produits
# Scraping page 71 : 35 produits
# Scraping page 72 : 35 produits
# Scraping page 73 : 35 produits
# Scraping page 74 : 35 produits
# Scraping page 75 : 35 produits
# Scraping page 76 : 35 produits
# Scraping page 77 : 35 produits
# Scraping page 78 : 35 produits
# Scraping page 79 : 35 produits
# Scraping page 80 : 35 produits
# Scraping page 81 : 35 produits
# Scraping page 82 : 35 produits
# Scraping page 83 : 35 produits
# Scraping page 84 : 35 produits
# Scraping page 85 : 35 produits
# Scraping page 86 : 35 produits
# Scraping page 87 : 35 produits
# Scraping page 88 : 35 produits
# Scraping page 89 : 35 produits
# Scraping page 90 : 35 produits
# Scraping page 91 : 35 produits
# Scraping page 92 : 35 produits
# Scraping page 93 : 35 produits
# Scraping page 94 : 35 produits
# Scraping page 95 : 35 produits
# Scraping page 96 : 35 produits
# Scraping page 97 : 35 produits
# Scraping page 98 : 35 produits
# Scraping page 99 : 35 produits
# Scraping page 100 : 35 produits
# Scraping page 101 : 35 produits
# Scraping page 102 : 35 produits
# Scraping page 103 : 35 produits
# Scraping page 104 : 35 produits
# Scraping page 105 : 35 produits
# Scraping page 106 : 35 produits
# Scraping page 107 : 35 produits
# Scraping page 108 : 35 produits
# Scraping page 109 : 35 produits
# Scraping page 110 : 35 produits
# Scraping page 111 : 35 produits
# Scraping page 112 : 35 produits
# Scraping page 113 : 35 produits
# Scraping page 114 : 35 produits
# Scraping page 115 : 35 produits
# Scraping page 116 : 35 produits
# Scraping page 117 : 35 produits
# Scraping page 118 : 35 produits
# Scraping page 119 : 35 produits
# Scraping page 120 : 35 produits
# Scraping page 121 : 35 produits
# Scraping page 122 : 35 produits
# Scraping page 123 : 35 produits
# Scraping page 124 : 35 produits
# Scraping page 125 : 35 produits
# Scraping page 126 : 35 produits
# Scraping page 127 : 35 produits
# Scraping page 128 : 35 produits
# Scraping page 129 : 35 produits
# Scraping page 130 : 35 produits
# Scraping page 131 : 35 produits
# Scraping page 132 : 35 produits
# Scraping page 133 : 35 produits
# Scraping page 134 : 35 produits
# Scraping page 135 : 35 produits
# Scraping page 136 : 35 produits
# Scraping page 137 : 35 produits
# Scraping page 138 : 35 produits
# Scraping page 139 : 35 produits
# Scraping page 140 : 35 produits
# Scraping page 141 : 35 produits
# Scraping page 142 : 35 produits
# Scraping page 143 : 35 produits
# Scraping page 144 : 35 produits
# Scraping page 145 : 35 produits
# Scraping page 146 : 35 produits
# Scraping page 147 : 35 produits
# Scraping page 148 : 35 produits
# Scraping page 149 : 35 produits
# Scraping page 150 : 35 produits
# Scraping page 151 : 35 produits
# Scraping page 152 : 35 produits
# Scraping page 153 : 35 produits
# Scraping page 154 : 35 produits
# Scraping page 155 : 35 produits
# Scraping page 156 : 35 produits
# Scraping page 157 : 35 produits
# Scraping page 158 : 35 produits
# Scraping page 159 : 35 produits
# Scraping page 160 : 35 produits
# Scraping page 161 : 35 produits
# Scraping page 162 : 35 produits
# Scraping page 163 : 35 produits
# Scraping page 164 : 35 produits
# Scraping page 165 : 35 produits
# Scraping page 166 : 35 produits
# Scraping page 167 : 35 produits
# Scraping page 168 : 35 produits
# Scraping page 169 : 35 produits
# Scraping page 170 : 35 produits
# Scraping page 171 : 35 produits
# Scraping page 172 : 35 produits
# Scraping page 173 : 35 produits
# Scraping page 174 : 35 produits
# Scraping page 175 : 35 produits
# Scraping page 176 : 35 produits
# Scraping page 177 : 35 produits
# Scraping page 178 : 35 produits
# Scraping page 179 : 35 produits
# Scraping page 180 : 35 produits
# Scraping page 181 : 35 produits
# Scraping page 182 : 35 produits
# Scraping page 183 : 35 produits
# Scraping page 184 : 35 produits
# Scraping page 185 : 35 produits
# Scraping page 186 : 35 produits
# Scraping page 187 : 35 produits
# Scraping page 188 : 35 produits
# Scraping page 189 : 35 produits
# Scraping page 190 : 35 produits
# Scraping page 191 : 35 produits
# Scraping page 192 : 35 produits
# Scraping page 193 : 35 produits
# Scraping page 194 : 35 produits
# Scraping page 195 : 35 produits
# Scraping page 196 : 35 produits
# Scraping page 197 : 35 produits
# Scraping page 198 : 35 produits
# Scraping page 199 : 35 produits
# Scraping page 200 : 35 produits
# Scraping page 201 : 35 produits
# Scraping page 202 : 35 produits
# Scraping page 203 : 35 produits
# Scraping page 204 : 35 produits
# Scraping page 205 : 35 produits
# Scraping page 206 : 35 produits
# Scraping page 207 : 35 produits
# Scraping page 208 : 35 produits
# Scraping page 209 : 35 produits
# Scraping page 210 : 35 produits
# Scraping page 211 : 35 produits
# Scraping page 212 : 35 produits
# Scraping page 213 : 35 produits
# Scraping page 214 : 35 produits
# Scraping page 215 : 35 produits
# Scraping page 216 : 35 produits
# Scraping page 217 : 35 produits
# Scraping page 218 : 35 produits
# Scraping page 219 : 35 produits
# Scraping page 220 : 33 produits
# Scraping page 221 : 0 produits
#
# Produits similaires trouvés :
#                                            product_name  price
# 0                                      Pommes bicolores   2.39
# 2                                  Pommes bicolores Bio   4.50
# 4                         Café moulu L'Original Bio MEO   7.25
# 6                             Filets de poulet Bio LOUE   8.96
# 8                 Pain de mie Complet Bio LA BOULANGERE   2.19
# ...                                                 ...    ...
# 7652             Céréales bio Muesli Super fruits BJORG   2.99
# 7673              Pain de mie Complet Bio LA BOULANGERE   2.19
# 7680                      Fromage Bio de Chèvre SOIGNON   2.96
# 7684  Corpore Sano - Huile D'argan Biologique 100% P...  28.99
# 7687             Céréales bio Muesli Super fruits BJORG   2.99
#
# [1735 rows x 2 columns]
#
# Nombre de produits similaires : 1735
# Prix estimé moyen : 15.41 €
# Prix minimum : 0.89 €, Prix maximum : 1109.75 €
